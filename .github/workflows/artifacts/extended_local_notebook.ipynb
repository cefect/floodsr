# %% [markdown]
# # Extended local notebook (Jupyter)
#
# Install-edge notebook shim for the documented in-notebook proof command.

# %%
import json, subprocess

payload = json.loads(subprocess.check_output(["floodsr", "doctor", "--json"], text=True))
assert payload["onnxruntime"]["installed"] is True
assert payload["gdal"]["vrt_enabled"] is True
assert payload["pcraster"]["installed"] is True
assert payload["pcraster"]["spreadzone_available"] is True
